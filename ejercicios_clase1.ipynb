# %% [markdown]
# # Python para Contadores — CPCES Salta
# ## Ejercicios de clase — Clase 1
#
# **Nombre:** ________________________________
# **Fecha:** ________________________________

# %% [markdown]
# ---
# # 🖊 Ejercicio 1 — Tu primera factura en Python
#
# Un proveedor te manda la siguiente factura. Tenés que representarla en Python usando variables, calcular el IVA y el total, y mostrar un resumen por pantalla.
#
# | Campo | Dato |
# |---|---|
# | Razón social | SERVICIOS INFORMÁTICOS SALTA S.R.L. |
# | CUIT | 30-68901234-5 |
# | Tipo de comprobante | Factura A |
# | Importe neto | $ 42.800,00 |
# | Alícuota IVA | 21% |
# | Período | 2024 |

# %% [markdown]
# ### Paso 1 — Definí las variables
#
# Recordá:
# - El importe neto va sin el signo `$` y con **punto** decimal: `42800.00`
# - El CUIT va entre comillas porque tiene guiones
# - La alícuota como decimal: 21% = `0.21`

# %%
# Definí una variable para cada campo de la factura
razon_social  = 
cuit          = 
tipo          = 
importe_neto  = 
alicuota      = 
periodo       =

# %% [markdown]
# ### Paso 2 — Calculá el IVA y el total

# %%
iva   = 
total =

# %% [markdown]
# ### Paso 3 — Mostrá el resumen
#
# Usá `print()` con f-strings para mostrar algo así:
#
# ```
# Proveedor : SERVICIOS INFORMÁTICOS SALTA S.R.L.
# CUIT      : 30-68901234-5
# Neto      : $ 42,800.00
# IVA 21%   : $ 8,988.00
# Total     : $ 51,788.00
# ```
#
# 💡 **Tip:** para separador de miles usá `{variable:,.2f}` dentro del f-string.

# %%
print(f'Proveedor : {razon_social}')
print(f'CUIT      : {cuit}')
print(f'Neto      : $ {importe_neto:,.2f}')
# Completá las líneas de IVA y total

# %% [markdown]
# ### Preguntas de reflexión
#
# Respondé en la celda de texto de abajo.

# %% [markdown]
# **1. ¿Qué pasa si escribís el importe como `42.800,00` con coma? Probalo en la celda de código y describí el error:**
#
# *(tu respuesta acá)*
#
# **2. ¿Cómo cambiaría el cálculo si la alícuota fuera 10,5%? ¿Qué variable modificarías?**
#
# *(tu respuesta acá)*

# %%
# Probá acá qué pasa con la coma decimal

# %% [markdown]
# ---
# # 🖊 Ejercicio 2 — Notebook documentado
#
# Tomá el trabajo del Ejercicio 1 y documentalo con Markdown para que parezca un informe profesional.

# %% [markdown]
# ### Paso 1 — Agregá un título
#
# Editá la celda de título al principio de este notebook para que incluya:
# - Un título principal con el nombre del análisis
# - Un subtítulo con el período
# - Tu nombre y la fecha
#
# Ejemplo:
# ```
# # Análisis de Factura de Proveedor
# ## Período: 2024
# **Alumno:** Tu nombre
# **Fecha:** Hoy
# ```

# %% [markdown]
# ### Paso 2 — Documentá cada sección
#
# Antes de cada celda de código del Ejercicio 1, insertá una celda de texto que explique en lenguaje contable qué hace ese paso.
#
# Ejemplos válidos:
# - *Definición de variables con los datos del comprobante*
# - *Cálculo del IVA 21% y del importe total*
# - *Resumen del comprobante para presentar al estudio*

# %% [markdown]
# ### Paso 3 — Exportar a HTML
#
# Una vez documentado el notebook:
# 1. Ir a **File → Download → Download .html**
# 2. Abrir el archivo `.html` en el navegador
# 3. Verificar que no se ve el código — solo los resultados y las explicaciones
#
# 🎯 **Criterio de éxito:** si alguien que no sabe Python puede leerlo y entender qué analizaste, está bien hecho.

# %% [markdown]
# ### Preguntas de reflexión
#
# Respondé en las celdas de texto de abajo.

# %% [markdown]
# **1. ¿En qué situaciones de tu trabajo actual usarías un notebook documentado como entregable?**
#
# *(tu respuesta acá)*

# %% [markdown]
# **2. ¿Qué ventaja tiene este formato frente a un Excel con comentarios?**
#
# *(tu respuesta acá)*

# %% [markdown]
# ---
# ## 📎 Para llevarte a casa
#
# Recordá guardar tu notebook antes de cerrar Colab:
# - **File → Save a copy in Drive** — guarda una copia en tu Google Drive
# - **File → Download → Download .ipynb** — guarda el archivo en tu computadora
