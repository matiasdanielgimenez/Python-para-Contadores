# %% [markdown]
# # Python para Contadores — CPCES Salta
# ## Ejercicios de práctica — Clase 1
#
# Este notebook contiene los ejercicios de práctica de la **Guía de Referencia de la Clase 1**.
# Están ordenados por tema. Hacé cada ejercicio en la celda de código correspondiente.
#
# **Nombre:** ________________________________
# **Fecha:** ________________________________

# %% [markdown]
# ---
# ## Ejercicio 0 — Tu primera celda en Colab
#
# Antes de arrancar con Python, familiarizate con el entorno.
#
# 1. En la celda de código de abajo, escribí el `print()` tal como aparece
# 2. Ejecutala con **Shift + Enter**
# 3. Fijate el número entre corchetes que aparece a la izquierda
# 4. Ejecutala una segunda vez y observá cómo cambia ese número

# %%
print("Hola, soy contador y estoy aprendiendo Python")

# %% [markdown]
# ---
# ## Ejercicio 1 — print() básico
#
# Escribí tres `print()` que muestren:
# - El nombre de un cliente ficticio
# - Su CUIT
# - El período fiscal que estás analizando
#
# Después combinalos en un solo `print()` usando `\n` para separar cada línea.

# %%
# Tres print() separados

# %%
# Un solo print() con \n

# %% [markdown]
# ---
# ## Ejercicio 2 — input() y tipos
#
# Usá `input()` para pedirle al usuario su CUIT y su razón social.
# Luego mostrálos con `print()`.
#
# **Bonus:** fijate qué pasa si intentás hacer una operación matemática con el resultado de `input()` sin convertirlo primero.

# %%
# Pedile al usuario su CUIT y razón social, luego mostrálos

# %%
# Bonus: ¿qué pasa si intentás multiplicar el resultado de input() por 2?

# %% [markdown]
# ---
# ## Ejercicio 3 — Validar CUITs con len()
#
# Creá dos variables:
# - `cuit_sin_guiones` con el valor `'20123456789'`
# - `cuit_con_guiones` con el valor `'20-12345678-9'`
#
# Usá `len()` en ambas y compará los resultados.
# ¿Cuál tiene 11 caracteres y cuál tiene 13?
# ¿Qué implicancia tiene esto para la limpieza de datos?

# %%
cuit_sin_guiones = '20123456789'
cuit_con_guiones = '20-12345678-9'

# Medí la longitud de cada uno

# %%
# ¿Cómo verificarías si un CUIT tiene el formato correcto?
# Tip: usá == para comparar el resultado de len() con el número esperado

# %% [markdown]
# ---
# ## Ejercicio 4 — Variables contables
#
# Creá variables para:
# - CUIT del emisor
# - Razón social del emisor
# - Importe neto
# - Alícuota de IVA
#
# Calculá el IVA y el importe total (neto + IVA).
# Mostrá todo con `print()`.
# Usá nombres de variables que tengan sentido contable.

# %%
# Definí las variables
cuit           = 
razon_social   = 
importe_neto   = 
alicuota       = 

# Calculá IVA y total
iva   = 
total = 

# Mostrá los resultados

# %% [markdown]
# ---
# ## Ejercicio 5 — Conversión de tipos
#
# Dado el string `'15000.75'` (simulando un importe que llegó de un CSV como texto):
#
# 1. Convertilo a `float`
# 2. Calculale el IVA al 21%
# 3. Convertí el resultado de vuelta a `string` y armá una oración con f-string
#
# **Bonus:** fijate qué pasa si intentás hacer la multiplicación sin convertir primero.

# %%
importe_str = '15000.75'   # llega del CSV como texto

# Convertí a float y calculá el IVA

# %%
# Armá una oración con f-string que incluya el importe original y el IVA calculado

# %%
# Bonus: ¿qué error obtenés si multiplicás importe_str * 0.21 sin convertir?

# %% [markdown]
# ---
# ## Ejercicio 6 — Operaciones y PEMDAS
#
# Tenés una factura de $48.500 con IVA al 10,5%. Calculá:
#
# 1. El importe del IVA (redondeado a 2 decimales)
# 2. El importe total
# 3. Cuánto le corresponde pagar a cada uno si el gasto se divide entre 3 personas
#
# Usá operadores compuestos (`+=`, `-=`) donde puedas.

# %%
importe_neto = 48500.00
alicuota     = 0.105

# Calculá el IVA redondeado a 2 decimales
iva = 

# Calculá el total usando un operador compuesto
total = importe_neto
total += 

# ¿Cuánto paga cada persona si son 3?
por_persona = 

print(f'IVA 10.5%:    $ {iva:,.2f}')
print(f'Total:        $ {total:,.2f}')
print(f'Por persona:  $ {por_persona:,.2f}')

# %% [markdown]
# ---
# ## Ejercicio 7 — F-strings y formato
#
# Con las variables que creaste en el Ejercicio 4 (CUIT, razón social, neto, IVA, total),
# generá una salida con f-string que imite el formato de un resumen de factura.
#
# El resultado tiene que verse así:
#
# ```
# Proveedor : NOMBRE DEL PROVEEDOR
# CUIT      : XX-XXXXXXXX-X
# Neto      : $ XX,XXX.XX
# IVA 21%   : $ X,XXX.XX
# Total     : $ XX,XXX.XX
# ```
#
# **Tip:** usá `{variable:,.2f}` para formato con separador de miles y 2 decimales.

# %%
# Si no ejecutaste el Ejercicio 4, definí las variables acá primero
# cuit         = ''
# razon_social = ''
# importe_neto = 
# alicuota     = 
# iva          = 
# total        = 

# Resumen de factura con f-strings
print(f'Proveedor : {razon_social}')
print(f'CUIT      : {cuit}')
print(f'Neto      : $ {importe_neto:,.2f}')
# Completá las líneas de IVA y total

# %% [markdown]
# ---
# ## Ejercicio 8 — Notebook documentado con Markdown
#
# Este ejercicio no tiene celda de código — es 100% Markdown.
#
# **Consigna:**
# 1. Insertá una celda de texto **arriba de cada ejercicio** que hayas resuelto y explicá en una oración qué hace ese bloque de código
# 2. Al principio del notebook, cambiá la celda de título para que incluya **tu nombre y la fecha**
# 3. Al final, agregá una celda de texto con una conclusión breve: ¿qué fue lo más difícil? ¿qué te resultó más útil?
#
# **Criterio:** si alguien que no sabe Python puede leer tu notebook y entender qué hiciste, está bien hecho.
#
# ---
# ### Tu conclusión va acá 👇

# %% [markdown]
# *(Escribí tu conclusión en esta celda de texto)*
